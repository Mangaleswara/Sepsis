# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Dataset.csv")

# %%
df
# Out:
#          Unnamed: 0  Hour     HR  O2Sat  Temp    SBP   MAP   DBP  Resp  EtCO2  \
# 0                 0     0    NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN
# 1                 1     1   65.0  100.0   NaN    NaN  72.0   NaN  16.5    NaN
# 2                 2     2   78.0  100.0   NaN    NaN  42.5   NaN   NaN    NaN
# 3                 3     3   73.0  100.0   NaN    NaN   NaN   NaN  17.0    NaN
# 4                 4     4   70.0  100.0   NaN  129.0  74.0  69.0  14.0    NaN
# ...             ...   ...    ...    ...   ...    ...   ...   ...   ...    ...
# 1552205          21    21   83.0   99.0   NaN  121.0  77.0  54.0  22.0    NaN
# 1552206          22    22   80.0   92.0   NaN  102.0  73.0  51.0  24.0    NaN
# 1552207          23    23   95.0   97.0  36.7  128.5  83.0  58.5  25.0    NaN
# 1552208          24    24  104.0   99.0   NaN  127.0  85.0  59.0  24.0    NaN
# 1552209          25    25   94.5   99.0   NaN  112.0  81.0  56.0  22.0    NaN
#
# ...

# %%
df.drop(columns=df.columns[0], axis=1, inplace=True)

# %%
df
# Out:
#          Hour     HR  O2Sat  Temp    SBP   MAP   DBP  Resp  EtCO2  BaseExcess  \
# 0           0    NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN
# 1           1   65.0  100.0   NaN    NaN  72.0   NaN  16.5    NaN         NaN
# 2           2   78.0  100.0   NaN    NaN  42.5   NaN   NaN    NaN         NaN
# 3           3   73.0  100.0   NaN    NaN   NaN   NaN  17.0    NaN         NaN
# 4           4   70.0  100.0   NaN  129.0  74.0  69.0  14.0    NaN         NaN
# ...       ...    ...    ...   ...    ...   ...   ...   ...    ...         ...
# 1552205    21   83.0   99.0   NaN  121.0  77.0  54.0  22.0    NaN         NaN
# 1552206    22   80.0   92.0   NaN  102.0  73.0  51.0  24.0    NaN         NaN
# 1552207    23   95.0   97.0  36.7  128.5  83.0  58.5  25.0    NaN         NaN
# 1552208    24  104.0   99.0   NaN  127.0  85.0  59.0  24.0    NaN         NaN
# 1552209    25   94.5   99.0   NaN  112.0  81.0  56.0  22.0    NaN         NaN
#
# ...

# %%
data = df[df["Patient_ID"]<=100000]

# %%
valid=df[df["Patient_ID"]>=100000]

# %%
valid
# Out:
#          Hour     HR  O2Sat  Temp    SBP   MAP   DBP  Resp  EtCO2  BaseExcess  \
# 790215      0    NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN
# 790216      1    NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN
# 790217      2   90.0  100.0  36.6  105.0  75.0  52.0  17.0    NaN         NaN
# 790218      3    NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN
# 790219      4   77.0  100.0   NaN  118.0  83.0  58.0  18.0    NaN         NaN
# ...       ...    ...    ...   ...    ...   ...   ...   ...    ...         ...
# 1552205    21   83.0   99.0   NaN  121.0  77.0  54.0  22.0    NaN         NaN
# 1552206    22   80.0   92.0   NaN  102.0  73.0  51.0  24.0    NaN         NaN
# 1552207    23   95.0   97.0  36.7  128.5  83.0  58.5  25.0    NaN         NaN
# 1552208    24  104.0   99.0   NaN  127.0  85.0  59.0  24.0    NaN         NaN
# 1552209    25   94.5   99.0   NaN  112.0  81.0  56.0  22.0    NaN         NaN
#
# ...

# %%
data.to_csv('raw_data1.csv')

# %%
valid.to_csv('raw_data2.csv')
